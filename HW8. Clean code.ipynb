# %% [markdown]
# У завданнях 1-4. Вам наданий простий код на Python, який не відповідає вказівкам PEP8. Ваше завдання — відредагувати код так, аби він відповідав PEP8. Напишіть після редагуванню коду, дотримання яких правил з pep8 ви досягли в відредагованій версії. Можна просто зазначити правило по суті, без конкретного номеру. Але якщо зазначите номер - взагалі супер. Також можна зазанчити використані правила коментарями по коду.
#
# Відредагований код має виконувати весь той самий функціонал, але бути написаний відповідно до вимог до гарного коду на Python! Не забудьте запустити відредагований код, він має бути робочим.

# %% [markdown]
# Завдання 1.

# %%
def greet(name):print(f"Hello, {name}")
def add(n1,n2):return n1+n2

x = 5;y = 3
display(greet("John"),add(x,y))
# Out:
# Hello, John
# None
# 8

# %%
def greet(name):
    print(f"Hello, {name}")

def add(n1, n2):
    x = 5
    y = 3
    return n1 + n2

display(greet("John"), add(x, y))
# Out:
# Hello, John
# None
# 8

# %% [markdown]
# - Використовуємо 4 пробіли або tab для відступу між рівнеми вкладеності.
# - Між функціями пропускаємо рядок для кращої читабельності.
# - Відстань між аргументами функції,  пробіл після коми.
# - Змінні x та y розташовані в окремих рядках для кращої читабельності.

# %% [markdown]
# Завдання 2.

# %%
from math import *
def calcArea(r):return pi*r**2
def calcCircumference(r):return 2*pi*r

radius=5
print("Area:",calcArea(radius),"Circumference:",calcCircumference(radius))
# Out:
# Area: 78.53981633974483 Circumference: 31.41592653589793

# %%
from math import pi

def calc_area(r):
    return pi * r ** 2

def calc_circumference(r):
    return 2 * pi * r

radius = 5
print("Area:", calc_area(radius), "Circumference:", calc_circumference(radius))
# Out:
# Area: 78.53981633974483 Circumference: 31.41592653589793

# %% [markdown]
# - Використання імпорту конкретних елементів з модуля (імпорт pi з math)
# - Використання snake_case для назв функцій та змінних.
# - Використовуємо 4 пробіли або tab для відступу між рівнями вкладеності.
# - Між функціями пропускаємо рядок для кращої читабельності.

# %% [markdown]
# Завдання 3.

# %%
class animal: pass
class dog(animal): 
    def __init__(self,name):
        self.name=name
        self.type='Dog'

# %%
class Animal:
    pass

class Dog(Animal):
    def __init__(self, name):
        self.name = name
        self.type = 'Dog'

# %% [markdown]
# - Імена класів animal і dog були перейменовані в Animal і Dog відповідно, використовуючи стиль CamelCase для іменування класів.
# - Додані пробіли навколо операторів присвоєння (=) для покращення читабельності.
# - Використовуємо 4 пробіли або tab для відступу між рівнями вкладеності.
# - можна ще додати докстрінги для класів і методів. Це може допомогти іншим розробникам легше розуміти, що робить цей код.

# %% [markdown]
# Завдання 4.

# %%
list=[1,2,3,4,5]
for i in range(len(list)):print(list[i])
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
my_list = [1, 2, 3, 4, 5]
for item in my_list:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# - Змінено ім'я змінної list на my_list, оскільки list є вбудованим ім'ям типу даних.
# - Додано пробіл після коми в списку my_list, щоб дотриматися вимог щодо роздільників між елементами списку.
# - Використано ітерацію без використання індексів через for item in my_list: замість for i in range(len(my_list)):. Це спрощує код і робить його більш читабельним. Так як у Python можна безпосередньо ітерувати через елементи списку без використання індексів.
# - Використовуємо 4 пробіли або tab для відступу між рівнями вкладеності.

# %% [markdown]
# 5.У вас є DataFrame df, що представляє результати тестів студентів з математики, англійської мови та історії. Поточний код обчислює середній бал для кожного студента шляхом ітерації за рядками DataFrame за допомогою iterrows().
#
# Ваше завдання полягає в тому, щоб змінити код так, аби уникнути використання iterrows() і замість цього застосувати більш ефективне та читабельне рішення відповідно до правил, озвучених у лекції. Рефакторинг треба зробити лише частині, де рахуються середні, імпорт і визначення датафрейму лишаємо без змін.

# %%
import pandas as pd

df = pd.DataFrame({
    'student': ['Alice', 'Bob', 'Charlie', 'David'],
    'math_score': [89, 94, 77, 85],
    'english_score': [92, 88, 79, 85],
    'history_score': [84, 92, 81, 89]
})

# %%
averages = []
for _, row in df.iterrows():
    averages.append((row['math_score'] + row['english_score'] + row['history_score']) / 3)

df['average_score'] = averages

# %%
averages
# Out:
# [88.33333333333333, 91.33333333333333, 79.0, 86.33333333333333]

# %% [markdown]
# Цей код можна покращити, використовуючи вбудовану функцію .mean() для обчислення середнього значення по рядку та векторизацію, що робить його більш ефективним та читабельним, порівняно з використанням ітерації за допомогою iterrows().
# Цей код використовує метод .mean(axis=1) для обчислення середнього балу по рядках Dataframe, використовуючи стовпці math_score, english_score та history_score.

# %%
df['average_score'] = df[['math_score', 'english_score', 'history_score']].mean(axis=1)

# %%
df
# Out:
#    student  math_score  english_score  history_score  average_score
# 0    Alice          89             92             84      88.333333
# 1      Bob          94             88             92      91.333333
# 2  Charlie          77             79             81      79.000000
# 3    David          85             85             89      86.333333

# %% [markdown]
# 6.У Вас є великий DataFrame df, що представляє транзакції продажу в магазині. Цей DataFrame містить понад 1 мільйон рядків і кілька стовпців, зокрема «product_name», «product_category», «product_price» і «transaction_date».
#
# І «product_name», і «product_category» є рядками, що представляють численні, але обмежені унікальні назви продуктів і категорії відповідно.
#
# Напишіть код для ефективного перетворення стовпців «product_name» і «product_category» на категорійний тип для ефективного використання пам’яті.
# Спробуйте вирішити це завдання, мінімізуючи використання пам'яті та зберігаючи читабельність коду. Крім того, виміряйте використання пам’яті до та після перетворення, щоб продемонструвати підвищення ефективності.
#
# Порівняйте кількість памʼяті, яку займає наданий набір даних і новий, створений Вами. В лекції був приклад. В скільки разів менше памʼяті займає новий датафрейм?

# %%
import pandas as pd
import numpy as np

np.random.seed(0)

products = ['apple', 'banana', 'cherry', 'dates', 'elderberry']
categories = ['fruit', 'fruit', 'fruit', 'fruit', 'fruit']

N_ROWS = 10**6
df = pd.DataFrame({
    'product_name': np.random.choice(products, N_ROWS),
    'product_category': np.random.choice(categories, N_ROWS),
    'product_price': np.random.uniform(1, 10, N_ROWS),
    'transaction_date': pd.date_range(start='1/1/2000', periods=N_ROWS, freq='h')
})
df.memory_usage(deep=True).sum()
# Out:
# 141398520

# %%
df.head(5)
# Out:
#   product_name product_category  product_price    transaction_date
# 0   elderberry            fruit       4.696674 2000-01-01 00:00:00
# 1        apple            fruit       7.176635 2000-01-01 01:00:00
# 2        dates            fruit       2.507932 2000-01-01 02:00:00
# 3        dates            fruit       2.079303 2000-01-01 03:00:00
# 4        dates            fruit       9.482386 2000-01-01 04:00:00

# %%
# Перетворимо стовпці на категорійний тип
categorical_cols = ['product_name', 'product_category']
for col in categorical_cols:
    df[col] = pd.Categorical(df[col])

# %%
df.memory_usage(deep=True).sum()
# Out:
# 18000787

# %%
print(f"Маємо зниження витрат памʼяті на {round((1-18000787/141398520)*100,2)}% !")
# Out:
# Маємо зниження витрат памʼяті на 87.27% !

# %% [markdown]
# 7.В цьому завданні кілька пунктів. Треба виконати усі послідовно.
#     7.1. Завантажте дані у pandas dataframe з файла `ecommerce_data.csv`. Обовʼязково при завантаженні вкажіть параметр `encoding = 'ISO-8859-1'`, без нього буде помилка.
#     7.2. Заповніть пропущені значення в колонці CustomerID на -1 та перетворіть тип цієї колонки на str, адже зараз вона типу float, а це не правильний тип даних для ідентифікатора клієнта.
#     7.3. З допомогою бібліотеки sweetviz побудуйте html звіт, який порівнює дані для країни "Germany" і країни "France". У Вас можуть виникнути багато попереджень (Warning), їх рекомендую вимкнути наступним шматком коду
#
#
#     import warnings
#
#     with warnings.catch_warnings(record=True):
#         # your code
#
#
#    7.4.Напишіть 5 відмінностей для двох зазначених країн на основі побудованого звіту, без виконання додаткового аналізу іншими інструментами.

# %%
df = pd.read_csv('ecommerce_data1.csv', encoding='ISO-8859-1')

# %%
display(df.head(5), df.shape)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice CustomerID         Country
# 0  12/1/2010 8:26       2.55    17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39    17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75    17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39    17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39    17850.0  United Kingdom
# (541909, 8)

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df['CustomerID'].fillna(-1, inplace=True)

# %%
df['CustomerID'] = df['CustomerID'].astype(str)

# %%
import sweetviz as sv
import warnings

with warnings.catch_warnings(record=True):
    report = sv.analyze(df)
report.show_html('ecommerce_compare_report.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report ecommerce_compare_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
with warnings.catch_warnings(record=True):
    compare_report = sv.compare(
    [df[df['Country'] == 'Germany'], 'Germany'], 
    [df[df['Country'] == 'France'], 'France']
)
compare_report.show_html('ecommerce_compare_report.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report ecommerce_compare_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# На основі звіту зі sweetviz 'ecommerce_compare_report.html' можемо проаналізувати, наприклад, як "Quantity" розподілена між країнами "Germany" і "France":
#
# - Загальна кількість значень (транзакцій): Для "Germany" кількість значень у колонці "Quantity" становить 9495, тоді як для "France" - 8557. Це може вказувати на те, що в країні "Germany" було проведено більше транзакцій.
#
# - Кількість унікальних значень: Кількість унікальних значень "Quantity" у країні "Germany" - 68, а в країні "France" - 77. Це може свідчити про більш різноманітний спектр кількостей товарів у транзакціях в країні "France".
#
# - Максимальне значення: Максимальне значення "Quantity" в країні "Germany" - 600, а в країні "France" - 912. Це може показувати, що в країні "France" були проведені транзакції з більшим обсягом товарів.
#
# - значення min для "Germany" (-288), а для "France" (-250). Це може вказувати на те, що в країні "Germany" були випадки з великими негативними значеннями кількості, більшими, ніж у "France".
#
# - 95-й відсоток: Значення 95-го відсотка "Quantity" у країні "Germany" - 32, а в країні "France" - 36. Це може вказувати на те, що в країні "France" деякі транзакції мали велику кількість товарів.
#
# - Стандартне відхилення: Стандартне відхилення "Quantity" у країні "Germany" - 17,9, а в країні "France" - 21,4. Більше значення стандартного відхилення для "France" може вказувати на більшу варіативність в кількості товарів у транзакціях.
#
# - Дисперсія (варіація) кількості товарів у замовленнях для країни "France" (459) більша, ніж для країни "Germany" (319), що також підкреслює більшу варіабельність кількості товарів у замовленнях для країни "France".
#
#
# Колонка "UnitPrice":
#
# - Середня ціна товарів (avg) у "Germany" (4) менше, ніж у "France" (5). Це може вказувати на те, що товари в "Germany" можуть бути дешевшими або проводяться акції.
# - Максимальна ціна за одиницю товару в "France" (4161) значно вища, ніж в "Germany" (600), що може вказувати на можливість наявності дорогих товарів або вибіркових покупок в "France".
#
# - В колонці StockCode товар з кодом "POST" складає 4% від загальної кількості як для "Germany", так і для "France". Це може вказувати на те, що обидві країни мають подібні товари з цим кодом у своїх даних, і цей товар є популярним або важливим для обох ринків.
#
# Враховуючи вищу середню кількість товарів у замовленні та більший діапазон кількості товарів для "France",  можна зосередити увагу бізнесу, наприклад, на рекламних акціях, що підтримують великі обсяги покупок. Також можна вивчити можливість пропозицій оптових знижок для замовників, які роблять великі замовлення.

# %% [markdown]
# 8.З допомогою ChatGPT виявіть, чи є та які помилки в наступному коді.
# Попросіть після цього переписати код із дотриманням PEP8. Проаналізуйте результат. Чи справді ChatGPT виправив всі стилістичні помилки? Якщо ні, напишіть йому ще кілька запитів, аби код відповідав вимогам PEP8.
# Вставте фінальну версію коду з чату у ноутбук та запустіть на заданому списку. Має вертатись 50.
# Напишіть, які промпти (інструкції) при зверненні до ChatGPT ви застосували та додайте скріншот(-и) з промптами та відповідями чата.
# Якщо зробили висновки при виконанні цього завдання, то діліться також :)
#
# **ЯК ВСТАВИТИ СКРІНШОТ в Jupyter Notebook** :
# 1. Створіть нову Markdown клітинку
# 2. В новоствореній клітинці обираєте в меню Jupyter Notebook Edit -> Insert Image
# 3. Обираєте картинку
# 4. В клітинці має зʼявитись текст, який містить картинку. Запустіть клітинку.
#
# Або можна просто перетягнути картинку в Markdown клітинку.

# %%
def CalculateVariance(nl):
    sum_list = 0
    for n in nl:
        sum_list = sum_list + n
    mean = sum_list / len(nl)
    sum_squares = 0
    for n in nl:
        sum_squares = sum_squares + n**2
    mean_squares = sum_squares / len(nl)
    return mean_squares

# %%
input_list = [75, 80, 85, 90, 95]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Can you help ensure this code adheres to PEP 8?
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
def calculate_variance(nl):
    sum_list = 0
    for n in nl:
        sum_list = sum_list + n
    mean = sum_list / len(nl)
    
    sum_squares = 0
    for n in nl:
        sum_squares = sum_squares + n**2
    mean_squares = sum_squares / len(nl)
    
    variance = mean_squares - (mean ** 2)
    
    return variance

input_list = [75, 80, 85, 90, 95]
result = calculate_variance(input_list)
print(result)
# Out:
# 50.0

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
def calculate_variance(nl):
    n = len(nl)
    if n == 0:
        raise ValueError("Input list cannot be empty")
    
    mean = sum(nl) / n
    mean_squares = sum(x ** 2 for x in nl) / n
    
    variance = mean_squares - mean ** 2
    
    return variance

input_list = [75, 80, 85, 90, 95]
result = calculate_variance(input_list)
print(result)
# Out:
# 50.0
